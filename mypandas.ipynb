# %%
import pandas as pd
import os

# %%
files = [ file for file in os.listdir(f'C:\Users\haric\Desktop\sales analytics\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]
all_months = pd.DataFrame()
for file in files:
    df = pd.read_csv(f'C:\Users\haric\Desktop\sales analytics\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data/'+file)
    all_months = pd.concat([all_months,df])
all_months.to_csv("all_data_csv",index = False)
# Out:
#   Cell In[8], line 1
#     files = [ file for file in os.listdir(f'C:\Users\haric\Desktop\sales analytics\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data')]
#                                                                                                                                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
import glob
import pandas as pd

# Get a list of all CSV files in the directory
csv_files = glob.glob(r'C:\Users\haric\Desktop\sales analytics\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\*.csv')

# Create an empty DataFrame
all_months = pd.DataFrame()

# Iterate over each CSV file and read it into a DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    all_months = pd.concat([all_months, df])

# Write the DataFrame to a CSV file
all_months.to_csv("all_data_csv", index=False)

# %%
all_months
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
all_month=pd.read_csv("all_data_csv")
all_month
# Out:
#         Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0                0   176558        USB-C Charging Cable                2
# 1                1      NaN                         NaN              NaN
# 2                2   176559  Bose SoundSport Headphones                1
# 3                3   176560                Google Phone                1
# 4                4   176560            Wired Headphones                1
# ...            ...      ...                         ...              ...
# 186845       11681   259353      AAA Batteries (4-pack)                3
# 186846       11682   259354                      iPhone                1
# 186847       11683   259355                      iPhone                1
# 186848       11684   259356      34in Ultrawide Monitor                1
# 186849       11685   259357        USB-C Charging Cable                1
#
#        Price Each      Order Date                         Purchase Address
# ...

# %%
nan_df = all_month[all_month.isna().any(axis=1)]
nan_df.head()
# Out:
#       Unnamed: 0 Order ID Product Quantity Ordered Price Each Order Date  \
# 1              1      NaN     NaN              NaN        NaN        NaN
# 356          356      NaN     NaN              NaN        NaN        NaN
# 735          735      NaN     NaN              NaN        NaN        NaN
# 1433        1433      NaN     NaN              NaN        NaN        NaN
# 1553        1553      NaN     NaN              NaN        NaN        NaN
#
#      Purchase Address
# 1                 NaN
# 356               NaN
# 735               NaN
# 1433              NaN
# 1553              NaN

# %%
all_month=all_month.dropna(how='all')
#all_month = all_month.drop('Unnamed: 0',axis=1)
#all_month=all_month.dropna(how='all')
all_month["Months"]= all_month["Order Date"].str[0:2]
#all_month['Months']= all_month['Order Date'].astype('int32')
all_month.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
all_month['Months']= all_month['Order Date'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\haric\Desktop\sales analytics\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\mypandas.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/haric/Desktop/sales%20analytics/Pandas-Data-Science-Tasks-master/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/mypandas.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> all_month['Months']= all_month['Order Date'].astype('int32')
#
# File c:\Users\haric\anaconda3\lib\site-packages\pandas\core\generic.py:5815, in NDFrame.astype(self, dtype, copy, errors)
#    5808     results = [
#    5809         self.iloc[:, i].astype(dtype, copy=copy)
#    5810         for i in range(len(self.columns))
#    5811     ]
#    5813 else:
#    5814     # else, only a single dtype is given
# ...

# %%
all_month= all_month[all_month["Order Date"].str[0:2]!="Or"]
all_month.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
#all_month['Months']= all_month['Order Date'].astype('int32')
all_month['Order Date'] = pd.to_datetime(all_month['Order Date'])

all_month
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address Months
# ...

# %%
#all_month = all_month.drop('Months',axis=1)
all_month["months"]=all_month["Order Date"].dt.month

# %%
all_month
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address  months
# ...

# %%
print(all_month['months'].dtype)
# Out:
# int64

# %%
#all_month.head()
all_month["Quantity Ordered"] = pd.to_numeric(all_month["Quantity Ordered"])
#print(all_month["Quantity Ordered"].dtype)
all_month["Price Each"]= pd.to_numeric(all_month["Price Each"])
print(all_month['Price Each'].dtype)
# Out:
# float64

# %%
all_month["sales"] = all_month["Price Each"]*all_month["Quantity Ordered"]
all_month.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  months   sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215       4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       4   11.99

# %% [markdown]
# now till now we have cleaned data and stuff but now we will find which month has more profit/sales

# %%
results = all_month.groupby("months").sum()
results
# Out:
#         Quantity Ordered  Price Each       sales
# months
# 1                  10903  1811768.38  1822256.73
# 2                  13449  2188884.72  2202022.42
# 3                  17005  2791207.83  2807100.38
# 4                  20558  3367671.02  3390670.24
# 5                  18667  3135125.13  3152606.75
# 6                  15253  2562025.61  2577802.26
# 7                  16072  2632539.56  2647775.76
# 8                  13448  2230345.42  2244467.88
# 9                  13109  2084992.09  2097560.13
# 10                 22703  3715554.83  3736726.88
# 11                 19798  3180600.68  3199603.20
# 12                 28114  4588415.41  4613443.34

# %%
print(results['sales'].max())
# Out:
# 4613443.34

# %%
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months,results["sales"])
plt.xticks(months)
#plt.yticks(results["sales"])
plt.xlabel("month numbers")
plt.ylabel("sales")
plt.show()

# %% [markdown]
# what city has the highest number of sales

# %%
all_month["city"] = all_month["Purchase Address"].apply(lambda x :  x.split(",")[1])
all_month["city"] =  all_month["city"].astype("str")
print(all_month["city"].dtype)
# Out:
# object

# %% [markdown]
# The apply function in pandas is a powerful and flexible tool that is used to apply a function along the axis of a DataFrame (either rows or columns).
# It is particularly useful for custom transformations, data cleaning, and feature engineering.

# %%
results2 = all_month.groupby("city").sum()
results2 = results2.reset_index()
#lets get the highest sales of sity with code
#results3 = results2["sales"].max()
results2
#down i have changed so pls check down also when you are further looking into it 114,115
# Out:
#                 city  Quantity Ordered  Price Each  months       sales
# 0         Atlanta GA             16602  2779908.20  104794  2795498.58
# 1          Austin TX             11153  1809873.61   69829  1819581.75
# 2          Boston MA             22528  3637409.77  141112  3661642.01
# 3          Dallas TX             16730  2752627.82  104620  2767975.40
# 4     Los Angeles CA             33289  5421435.23  208325  5452570.80
# 5   New York City NY             27932  4635370.83  175741  4664317.43
# 6        Portland ME              2750   447189.25   17144   449758.27
# 7        Portland OR             11303  1860558.22   70621  1870732.34
# 8   San Francisco CA             50239  8211461.74  315520  8262203.91
# 9         Seattle WA             16553  2733296.01  104941  2747755.48

# %%
max_sales_city = results2[results2['sales'] == results2['sales'].max()]['city'].values[0]
max_sales_city
# Out:
# ' San Francisco'

# %% [markdown]
# we can also write the function which is given below

# %%
def getting_city(address):
    return address.split(",")[1]
all_month["city"] = all_month["Purchase Address"].apply(lambda x : getting_city(x))

# %%
def getting_city(address):
    return address.split(",")[1]

def getting_state(address):
    return address.split(",")[2].split(" ")[1]
all_month["city"] = all_month["Purchase Address"].apply(lambda x : getting_city(x)+" "+getting_state(x))
all_month["city"]
# Out:
# 0                 Dallas TX
# 2                 Boston MA
# 3            Los Angeles CA
# 4            Los Angeles CA
# 5            Los Angeles CA
#                 ...
# 186845       Los Angeles CA
# 186846     San Francisco CA
# 186847     San Francisco CA
# 186848     San Francisco CA
# 186849     San Francisco CA
# Name: city, Length: 185950, dtype: object

# %%
results2 = all_month.groupby("city").sum()
results2 = results2.reset_index()
#lets get the highest sales of sity with code
#results3 = results2["sales"].max()
results2
# Out:
#                 city  Quantity Ordered  Price Each  months       sales
# 0         Atlanta GA             16602  2779908.20  104794  2795498.58
# 1          Austin TX             11153  1809873.61   69829  1819581.75
# 2          Boston MA             22528  3637409.77  141112  3661642.01
# 3          Dallas TX             16730  2752627.82  104620  2767975.40
# 4     Los Angeles CA             33289  5421435.23  208325  5452570.80
# 5   New York City NY             27932  4635370.83  175741  4664317.43
# 6        Portland ME              2750   447189.25   17144   449758.27
# 7        Portland OR             11303  1860558.22   70621  1870732.34
# 8   San Francisco CA             50239  8211461.74  315520  8262203.91
# 9         Seattle WA             16553  2733296.01  104941  2747755.48

# %%
import matplotlib.pyplot as plt
cities = [city for city,df in all_month.groupby("city")]
plt.bar(cities,results2["sales"])
plt.xticks(cities, rotation = "vertical",size = 8)
#plt.yticks(results["sales"])
plt.xlabel("cities")
plt.ylabel("sales")
plt.show()

# %% [markdown]
# This line of code is using a list comprehension to iterate over the groups created by groupby("city") in the DataFrame all_month. The df variable represents each subgroup (subset of the DataFrame) corresponding to a unique city, and city represents the city name.

# %%
citiesuuuu = [city for city,df in all_month.groupby("city")]
citiesuuuu
# Out:
# [' Atlanta GA',
#  ' Austin TX',
#  ' Boston MA',
#  ' Dallas TX',
#  ' Los Angeles CA',
#  ' New York City NY',
#  ' Portland ME',
#  ' Portland OR',
#  ' San Francisco CA',
#  ' Seattle WA']

# %% [markdown]
# now  let us find in which time we need to advertise more so that we can increase our sales

# %%
all_month.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  months   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215       4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               city
# 0        Dallas TX
# 2        Boston MA
# 3   Los Angeles CA
# ...

# %%
all_month["Hour"] = all_month["Order Date"].dt.hour 
all_month["Minutes"] = all_month["Order Date"].dt.minute
all_month.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  months   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215       4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               city  Hour  Minutes
# 0        Dallas TX     8       46
# ...

# %%
results4 = all_month.groupby("Hour").count()
results4 = results4.reset_index()
results4.head()
# Out:
#    Hour  Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0     0      3910     3910              3910        3910        3910
# 1     1      2350     2350              2350        2350        2350
# 2     2      1243     1243              1243        1243        1243
# 3     3       831      831               831         831         831
# 4     4       854      854               854         854         854
#
#    Purchase Address  months  sales  city  Minutes
# 0              3910    3910   3910  3910     3910
# 1              2350    2350   2350  2350     2350
# 2              1243    1243   1243  1243     1243
# 3               831     831    831   831      831
# 4               854     854    854   854      854

# %%
import matplotlib.pyplot as plt
hours = [hour for hour,df in all_month.groupby("Hour")]
plt.bar(hours,results4["Quantity Ordered"])
plt.xticks(hours, rotation = "vertical",size = 8)
#plt.yticks(results["sales"])
plt.xlabel("hours")
plt.ylabel("sales")
#plt.grid()
plt.show()

# %% [markdown]
# Now lets finf what are the products that are most often sold together

# %% [markdown]
# all_month.groupby("Order ID")['Product']:
#
# This groups the DataFrame all_month by the "Order ID" column and selects the 'Product' column for further processing.

# %% [markdown]
# In the context of the duplicated method in pandas, the keep parameter determines which occurrences of a duplicated value should be marked as True and which ones as False. The keep parameter can take the following values:
#
# keep='first' (default): Marks all occurrences as True except for the first occurrence of each duplicated value. This means that the first occurrence is considered not duplicated, and subsequent occurrences are marked as duplicated.
#
# keep='last': Marks all occurrences as True except for the last occurrence of each duplicated value. This means that the last occurrence is considered not duplicated, and previous occurrences are marked as duplicated.
#
# keep=False: Marks all occurrences of a duplicated value as True. This means that all occurrences of a duplicated value are considered as duplicates.
#
# The reason why keep=False is used in your code is to identify and mark all occurrences of duplicated values, not distinguishing between the first or last occurrence. All instances of a duplicated "Order ID" in the specified column will be marked as True using this setting.

# %%
df1 = all_month[all_month["Order ID"].duplicated(keep=False)]
df1["Grouped_products"] = all_month.groupby("Order ID")['Product'].transform(lambda x : ','.join(x))
df1.head()
# Out:
# C:\Users\haric\AppData\Local\Temp\ipykernel_25932\3326900380.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Grouped_products"] = all_month.groupby("Order ID")['Product'].transform(lambda x : ','.join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address  months   sales  \
# ...

# %%
df1= df1[["Order ID","Grouped_products"]].drop_duplicates()
df1
# Out:
#        Order ID                                   Grouped_products
# 3        176560                      Google Phone,Wired Headphones
# 18       176574                  Google Phone,USB-C Charging Cable
# 30       176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32       176586                AAA Batteries (4-pack),Google Phone
# 119      176672      Lightning Charging Cable,USB-C Charging Cable
# ...         ...                                                ...
# 186781   259296  Apple Airpods Headphones,Apple Airpods Headphones
# 186783   259297  iPhone,Lightning Charging Cable,Lightning Char...
# 186791   259303       34in Ultrawide Monitor,AA Batteries (4-pack)
# 186803   259314            Wired Headphones,AAA Batteries (4-pack)
# 186841   259350                  Google Phone,USB-C Charging Cable
#
# [7136 rows x 2 columns]

# %%
from itertools import combinations
from collections import Counter
count = Counter()
for row in df1["Grouped_products"]:
    rowlist = row .split(',')
    count.update(Counter(combinations(rowlist,3)))
#print(count)

for key,value in count.most_common(5):
    print(key,value)
# Out:
# ('Google Phone', 'USB-C Charging Cable', 'Wired Headphones') 87
# ('iPhone', 'Lightning Charging Cable', 'Wired Headphones') 62
# ('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones') 47
# ('Google Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones') 35
# ('Vareebadd Phone', 'USB-C Charging Cable', 'Wired Headphones') 33

# %%
import matplotlib.pyplot as plt
product_group = all_month.groupby("Product")
quantity_ordered = product_group.sum()['Quantity Ordered']
products = [product for product,df in product_group]
plt.bar(products,quantity_ordered)
plt.xticks(products,rotation= "vertical",size = 10)
#plt.yticks(results["sales"])
plt.xlabel("products")
plt.ylabel("quantity")
#plt.grid()
plt.show()

# %% [markdown]
# in the above you can see all the products with respective of their quantity

# %%
#product_group.head()
quantity_ordered
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
prices = all_month.groupby("Product").mean()['Price Each']
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
prices = all_month.groupby("Product").mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

ax1.bar(products, quantity_ordered, color='g') 
ax2.plot(products, prices, 'b')
ax1.set_xlabel('Product Name') 
ax1.set_ylabel('Quantity Ordered', color='g')

ax2.set_ylabel('Price ($)', color='b')

ax1.set_xticklabels(products, rotation='vertical', size=8)
# Out:
# C:\Users\haric\AppData\Local\Temp\ipykernel_25932\746392793.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation='vertical', size=8)
# [Text(0, 0, '20in Monitor'),
#  Text(1, 0, '27in 4K Gaming Monitor'),
#  Text(2, 0, '27in FHD Monitor'),
#  Text(3, 0, '34in Ultrawide Monitor'),
#  Text(4, 0, 'AA Batteries (4-pack)'),
#  Text(5, 0, 'AAA Batteries (4-pack)'),
#  Text(6, 0, 'Apple Airpods Headphones'),
#  Text(7, 0, 'Bose SoundSport Headphones'),
#  Text(8, 0, 'Flatscreen TV'),
#  Text(9, 0, 'Google Phone'),
#  Text(10, 0, 'LG Dryer'),
#  Text(11, 0, 'LG Washing Machine'),
#  Text(12, 0, 'Lightning Charging Cable'),
#  Text(13, 0, 'Macbook Pro Laptop'),
#  Text(14, 0, 'ThinkPad Laptop'),
#  Text(15, 0, 'USB-C Charging Cable'),
#  Text(16, 0, 'Vareebadd Phone'),
#  Text(17, 0, 'Wired Headphones'),
#  Text(18, 0, 'iPhone')]

# %% [markdown]
# in the above graph we can see the quantity and product and also their  prices where we got the quantity with help of above  question  :-)
